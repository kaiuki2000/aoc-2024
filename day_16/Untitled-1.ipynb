# %%
with open('input.txt') as f:
    maze = f.read().splitlines()
# maze

# Get adjecent positions
def get_adjacent(matrix, i, j):
    """Return a list of adjacent positions of (i, j) in a matrix"""
    L1, L2 = len(matrix), len(matrix[0])
    adjacent = []
    if i > 0:
        adjacent.append((i-1, j))
    if i < L1 - 1:
        adjacent.append((i+1, j))
    if j > 0:
        adjacent.append((i, j-1))
    if j < L2 - 1:
        adjacent.append((i, j+1))
    return adjacent

def is_dead_end(maze, i, j):
    """Check if the given coordinates are a dead end in the maze."""
    adjacent = [position for position in get_adjacent(maze, i, j) if maze[position[0]][position[1]] in '#X']
    if(len(adjacent) == 3):
        return True
    return False

# %%
from collections import defaultdict

# Define the unvisited set: dictionary with positions as keys and values as the cost to reach that position.
unvisited = defaultdict(list) # 1e9 is the cost to reach that position, 'X' is the previous position ('direction')
for i in range(len(maze)):
    for j in range(len(maze[0])):
        if maze[i][j] in '.E':
            unvisited[(i, j)] = [1e9]
        elif maze[i][j] in 'S':
            print(f'Starting position: ({i}, {j})')
            unvisited[(i, j)] = [0]

# This will store all the ways to get to position (i, j) with the cost as the value ((i, j) : cost)
cost_dict = defaultdict(list)

# Sort the unvisited set by cost
unvisited = dict(sorted(unvisited.items(), key=lambda item: min(item[1])))

# Define the visited set: dictionary with positions as keys and values as the cost to reach that position.
visited = defaultdict(list) # 1e9 is the cost to reach that position, 'X' is the previous position ('direction')
# Out:
# Starting position: (139, 1)

# %%
def get_direction(dx, dy):
    """Return the direction given the change in x and y."""
    if dx == 0 and dy == 1:
        return 'East'
    elif dx == 0 and dy == -1:
        return 'West'
    elif dx == 1 and dy == 0:
        return 'South'
    elif dx == -1 and dy == 0:
        return 'North'

# %%
# Dijkstra's algorithm
start = (139, 1)  # Start position
end = (1, 139)    # End position

previous_position = start
first_flag = True

while True:
    # Current position: (i, j) with minimum cost to reach it.
    i, j = list(unvisited.keys())[0]
    print(f'Current position: ({i}, {j}); unvisited: {unvisited[(i, j)]}')
    if maze[i][j] == 'E':
        break

    adjacent = [position for position in get_adjacent(maze, i, j) if             \
               (maze[position[0]][position[1]] in '.E' and position in unvisited)]
    print(f'Adjacent positions: {adjacent}')

    if first_flag:
        prev_direction = 'East'
        first_flag = False
    else:
        dx_p, dy_p = i - previous_position[0], j - previous_position[1]
        print(f'Previous position: {previous_position}; dx_p: {dx_p}; dy_p: {dy_p}')
        prev_direction = get_direction(dx_p, dy_p)

    for position in adjacent:
        # Distance from adjacent position to current position.
        # A change in direction costs 1001, otherwise 1.
        dx, dy = position[0] - i, position[1] - j
        new_direction = get_direction(dx, dy)

        print(f'Previous direction: {prev_direction}; New direction: {new_direction}')

        if new_direction != prev_direction: distance = 1001
        else: distance = 1
            
        # Update the cost to reach the adjacent position.
        if unvisited[position][0] == 1e9:
            unvisited[position] = [min(unvisited[(i, j)]) + distance]
        else:
            unvisited[position].append(min(min(unvisited[position]), min(unvisited[(i, j)]) + distance))
        print(f'Updated cost to reach ({position}): {unvisited[position]}')

    # Add the current position to the visited set.
    visited[(i, j)] = unvisited[(i, j)]

    # Remove the current position from the unvisited set (defaultdict).
    del unvisited[(i, j)]

    # Update the previous position.
    previous_position = (i, j)

    # Re-sort the unvisited set by cost
    unvisited = dict(sorted(unvisited.items(), key=lambda item: min(item[1])))

    print(f'\n *** *** \n')

# The cost to reach the exit.
unvisited[(i, j)]
# Out:
# Current position: (139, 1); unvisited: [0]
# Adjacent positions: [(138, 1), (139, 2)]
# Previous direction: East; New direction: North
# Updated cost to reach ((138, 1)): [1001]
# Previous direction: East; New direction: East
# Updated cost to reach ((139, 2)): [1]
#
#  *** ***
#
# Current position: (139, 2); unvisited: [1]
# Adjacent positions: [(139, 3)]
# Previous position: (139, 1); dx_p: 0; dy_p: 1
# Previous direction: East; New direction: East
# Updated cost to reach ((139, 3)): [2]
#
#  *** ***
#
# Current position: (139, 3); unvisited: [2]
# Adjacent positions: [(138, 3)]
# Previous position: (139, 2); dx_p: 0; dy_p: 1
# Previous direction: East; New direction: North
# Updated cost to reach ((138, 3)): [1003]
#
#  *** ***
#
# Current position: (138, 1); unvisited: [1001]
# Adjacent positions: [(137, 1)]
# Previous position: (139, 3); dx_p: -1; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((137, 1)): [2002]
#
#  *** ***
#
# Current position: (138, 3); unvisited: [1003]
# Adjacent positions: [(137, 3)]
# Previous position: (138, 1); dx_p: 0; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((137, 3)): [2004]
#
#  *** ***
#
# Current position: (137, 1); unvisited: [2002]
# Adjacent positions: [(136, 1), (137, 2)]
# Previous position: (138, 3); dx_p: -1; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((136, 1)): [3003]
# Previous direction: None; New direction: East
# Updated cost to reach ((137, 2)): [3003]
#
#  *** ***
#
# Current position: (137, 3); unvisited: [2004]
# Adjacent positions: [(137, 2)]
# Previous position: (137, 1); dx_p: 0; dy_p: 2
# Previous direction: None; New direction: West
# Updated cost to reach ((137, 2)): [3003, 3003]
#
#  *** ***
#
# Current position: (136, 1); unvisited: [3003]
# Adjacent positions: [(135, 1)]
# Previous position: (137, 3); dx_p: -1; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((135, 1)): [4004]
#
#  *** ***
#
# Current position: (137, 2); unvisited: [3003, 3003]
# Adjacent positions: []
# Previous position: (136, 1); dx_p: 1; dy_p: 1
#
#  *** ***
#
# Current position: (135, 1); unvisited: [4004]
# Adjacent positions: [(134, 1), (135, 2)]
# Previous position: (137, 2); dx_p: -2; dy_p: -1
# Previous direction: None; New direction: North
# Updated cost to reach ((134, 1)): [5005]
# Previous direction: None; New direction: East
# Updated cost to reach ((135, 2)): [5005]
#
#  *** ***
#
# Current position: (134, 1); unvisited: [5005]
# Adjacent positions: [(133, 1)]
# Previous position: (135, 1); dx_p: -1; dy_p: 0
# Previous direction: North; New direction: North
# Updated cost to reach ((133, 1)): [5006]
#
#  *** ***
#
# Current position: (135, 2); unvisited: [5005]
# Adjacent positions: [(135, 3)]
# Previous position: (134, 1); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((135, 3)): [6006]
#
#  *** ***
#
# Current position: (133, 1); unvisited: [5006]
# Adjacent positions: [(133, 2)]
# Previous position: (135, 2); dx_p: -2; dy_p: -1
# Previous direction: None; New direction: East
# Updated cost to reach ((133, 2)): [6007]
#
#  *** ***
#
# Current position: (135, 3); unvisited: [6006]
# Adjacent positions: [(135, 4)]
# Previous position: (133, 1); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((135, 4)): [7007]
#
#  *** ***
#
# Current position: (133, 2); unvisited: [6007]
# Adjacent positions: [(133, 3)]
# Previous position: (135, 3); dx_p: -2; dy_p: -1
# Previous direction: None; New direction: East
# Updated cost to reach ((133, 3)): [7008]
#
#  *** ***
#
# Current position: (135, 4); unvisited: [7007]
# Adjacent positions: [(135, 5)]
# Previous position: (133, 2); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((135, 5)): [8008]
#
#  *** ***
#
# Current position: (133, 3); unvisited: [7008]
# Adjacent positions: [(132, 3)]
# Previous position: (135, 4); dx_p: -2; dy_p: -1
# Previous direction: None; New direction: North
# Updated cost to reach ((132, 3)): [8009]
#
#  *** ***
#
# Current position: (135, 5); unvisited: [8008]
# Adjacent positions: [(136, 5)]
# Previous position: (133, 3); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: South
# Updated cost to reach ((136, 5)): [9009]
#
#  *** ***
#
# Current position: (132, 3); unvisited: [8009]
# Adjacent positions: [(131, 3)]
# Previous position: (135, 5); dx_p: -3; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((131, 3)): [9010]
#
#  *** ***
#
# Current position: (136, 5); unvisited: [9009]
# Adjacent positions: [(137, 5)]
# Previous position: (132, 3); dx_p: 4; dy_p: 2
# Previous direction: None; New direction: South
# Updated cost to reach ((137, 5)): [10010]
#
#  *** ***
#
# Current position: (131, 3); unvisited: [9010]
# Adjacent positions: [(131, 4)]
# Previous position: (136, 5); dx_p: -5; dy_p: -2
# Previous direction: None; New direction: East
# Updated cost to reach ((131, 4)): [10011]
#
#  *** ***
#
# Current position: (137, 5); unvisited: [10010]
# Adjacent positions: [(138, 5)]
# Previous position: (131, 3); dx_p: 6; dy_p: 2
# Previous direction: None; New direction: South
# Updated cost to reach ((138, 5)): [11011]
#
#  *** ***
#
# Current position: (131, 4); unvisited: [10011]
# Adjacent positions: [(131, 5)]
# Previous position: (137, 5); dx_p: -6; dy_p: -1
# Previous direction: None; New direction: East
# Updated cost to reach ((131, 5)): [11012]
#
#  *** ***
#
# Current position: (138, 5); unvisited: [11011]
# Adjacent positions: [(139, 5)]
# Previous position: (131, 4); dx_p: 7; dy_p: 1
# Previous direction: None; New direction: South
# Updated cost to reach ((139, 5)): [12012]
#
#  *** ***
#
# Current position: (131, 5); unvisited: [11012]
# Adjacent positions: [(132, 5), (131, 6)]
# Previous position: (138, 5); dx_p: -7; dy_p: 0
# Previous direction: None; New direction: South
# Updated cost to reach ((132, 5)): [12013]
# Previous direction: None; New direction: East
# Updated cost to reach ((131, 6)): [12013]
#
#  *** ***
#
# Current position: (139, 5); unvisited: [12012]
# Adjacent positions: [(139, 6)]
# Previous position: (131, 5); dx_p: 8; dy_p: 0
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 6)): [13013]
#
#  *** ***
#
# Current position: (131, 6); unvisited: [12013]
# Adjacent positions: [(131, 7)]
# Previous position: (139, 5); dx_p: -8; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((131, 7)): [13014]
#
#  *** ***
#
# Current position: (132, 5); unvisited: [12013]
# Adjacent positions: [(133, 5)]
# Previous position: (131, 6); dx_p: 1; dy_p: -1
# Previous direction: None; New direction: South
# Updated cost to reach ((133, 5)): [13014]
#
#  *** ***
#
# Current position: (139, 6); unvisited: [13013]
# Adjacent positions: [(139, 7)]
# Previous position: (132, 5); dx_p: 7; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 7)): [14014]
#
#  *** ***
#
# Current position: (131, 7); unvisited: [13014]
# Adjacent positions: [(130, 7)]
# Previous position: (139, 6); dx_p: -8; dy_p: 1
# Previous direction: None; New direction: North
# Updated cost to reach ((130, 7)): [14015]
#
#  *** ***
#
# Current position: (133, 5); unvisited: [13014]
# Adjacent positions: [(133, 6)]
# Previous position: (131, 7); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: East
# Updated cost to reach ((133, 6)): [14015]
#
#  *** ***
#
# Current position: (139, 7); unvisited: [14014]
# Adjacent positions: [(139, 8)]
# Previous position: (133, 5); dx_p: 6; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 8)): [15015]
#
#  *** ***
#
# Current position: (130, 7); unvisited: [14015]
# Adjacent positions: [(129, 7)]
# Previous position: (139, 7); dx_p: -9; dy_p: 0
# Previous direction: None; New direction: North
# Updated cost to reach ((129, 7)): [15016]
#
#  *** ***
#
# Current position: (133, 6); unvisited: [14015]
# Adjacent positions: [(133, 7)]
# Previous position: (130, 7); dx_p: 3; dy_p: -1
# Previous direction: None; New direction: East
# Updated cost to reach ((133, 7)): [15016]
#
#  *** ***
#
# Current position: (139, 8); unvisited: [15015]
# Adjacent positions: [(139, 9)]
# Previous position: (133, 6); dx_p: 6; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 9)): [16016]
#
#  *** ***
#
# Current position: (129, 7); unvisited: [15016]
# Adjacent positions: [(129, 6), (129, 8)]
# Previous position: (139, 8); dx_p: -10; dy_p: -1
# Previous direction: None; New direction: West
# Updated cost to reach ((129, 6)): [16017]
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 8)): [16017]
#
#  *** ***
#
# Current position: (133, 7); unvisited: [15016]
# Adjacent positions: [(133, 8)]
# Previous position: (129, 7); dx_p: 4; dy_p: 0
# Previous direction: None; New direction: East
# Updated cost to reach ((133, 8)): [16017]
#
#  *** ***
#
# Current position: (139, 9); unvisited: [16016]
# Adjacent positions: [(139, 10)]
# Previous position: (133, 7); dx_p: 6; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 10)): [17017]
#
#  *** ***
#
# Current position: (129, 6); unvisited: [16017]
# Adjacent positions: [(129, 5)]
# Previous position: (139, 9); dx_p: -10; dy_p: -3
# Previous direction: None; New direction: West
# Updated cost to reach ((129, 5)): [17018]
#
#  *** ***
#
# Current position: (129, 8); unvisited: [16017]
# Adjacent positions: [(129, 9)]
# Previous position: (129, 6); dx_p: 0; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 9)): [17018]
#
#  *** ***
#
# Current position: (133, 8); unvisited: [16017]
# Adjacent positions: [(133, 9)]
# Previous position: (129, 8); dx_p: 4; dy_p: 0
# Previous direction: None; New direction: East
# Updated cost to reach ((133, 9)): [17018]
#
#  *** ***
#
# Current position: (139, 10); unvisited: [17017]
# Adjacent positions: [(139, 11)]
# Previous position: (133, 8); dx_p: 6; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 11)): [18018]
#
#  *** ***
#
# Current position: (129, 5); unvisited: [17018]
# Adjacent positions: [(129, 4)]
# Previous position: (139, 10); dx_p: -10; dy_p: -5
# Previous direction: None; New direction: West
# Updated cost to reach ((129, 4)): [18019]
#
#  *** ***
#
# Current position: (129, 9); unvisited: [17018]
# Adjacent positions: [(129, 10)]
# Previous position: (129, 5); dx_p: 0; dy_p: 4
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 10)): [18019]
#
#  *** ***
#
# Current position: (133, 9); unvisited: [17018]
# Adjacent positions: [(132, 9)]
# Previous position: (129, 9); dx_p: 4; dy_p: 0
# Previous direction: None; New direction: North
# Updated cost to reach ((132, 9)): [18019]
#
#  *** ***
#
# Current position: (139, 11); unvisited: [18018]
# Adjacent positions: [(139, 12)]
# Previous position: (133, 9); dx_p: 6; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 12)): [19019]
#
#  *** ***
#
# Current position: (129, 4); unvisited: [18019]
# Adjacent positions: [(129, 3)]
# Previous position: (139, 11); dx_p: -10; dy_p: -7
# Previous direction: None; New direction: West
# Updated cost to reach ((129, 3)): [19020]
#
#  *** ***
#
# Current position: (129, 10); unvisited: [18019]
# Adjacent positions: [(129, 11)]
# Previous position: (129, 4); dx_p: 0; dy_p: 6
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 11)): [19020]
#
#  *** ***
#
# Current position: (132, 9); unvisited: [18019]
# Adjacent positions: [(131, 9)]
# Previous position: (129, 10); dx_p: 3; dy_p: -1
# Previous direction: None; New direction: North
# Updated cost to reach ((131, 9)): [19020]
#
#  *** ***
#
# Current position: (139, 12); unvisited: [19019]
# Adjacent positions: [(139, 13)]
# Previous position: (132, 9); dx_p: 7; dy_p: 3
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 13)): [20020]
#
#  *** ***
#
# Current position: (129, 3); unvisited: [19020]
# Adjacent positions: [(128, 3), (129, 2)]
# Previous position: (139, 12); dx_p: -10; dy_p: -9
# Previous direction: None; New direction: North
# Updated cost to reach ((128, 3)): [20021]
# Previous direction: None; New direction: West
# Updated cost to reach ((129, 2)): [20021]
#
#  *** ***
#
# Current position: (129, 11); unvisited: [19020]
# Adjacent positions: [(128, 11), (129, 12)]
# Previous position: (129, 3); dx_p: 0; dy_p: 8
# Previous direction: None; New direction: North
# Updated cost to reach ((128, 11)): [20021]
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 12)): [20021]
#
#  *** ***
#
# Current position: (131, 9); unvisited: [19020]
# Adjacent positions: [(131, 10)]
# Previous position: (129, 11); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: East
# Updated cost to reach ((131, 10)): [20021]
#
#  *** ***
#
# Current position: (139, 13); unvisited: [20020]
# Adjacent positions: [(138, 13), (139, 14)]
# Previous position: (131, 9); dx_p: 8; dy_p: 4
# Previous direction: None; New direction: North
# Updated cost to reach ((138, 13)): [21021]
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 14)): [21021]
#
#  *** ***
#
# Current position: (128, 3); unvisited: [20021]
# Adjacent positions: [(127, 3)]
# Previous position: (139, 13); dx_p: -11; dy_p: -10
# Previous direction: None; New direction: North
# Updated cost to reach ((127, 3)): [21022]
#
#  *** ***
#
# Current position: (129, 2); unvisited: [20021]
# Adjacent positions: [(129, 1)]
# Previous position: (128, 3); dx_p: 1; dy_p: -1
# Previous direction: None; New direction: West
# Updated cost to reach ((129, 1)): [21022]
#
#  *** ***
#
# Current position: (128, 11); unvisited: [20021]
# Adjacent positions: [(127, 11)]
# Previous position: (129, 2); dx_p: -1; dy_p: 9
# Previous direction: None; New direction: North
# Updated cost to reach ((127, 11)): [21022]
#
#  *** ***
#
# Current position: (129, 12); unvisited: [20021]
# Adjacent positions: [(129, 13)]
# Previous position: (128, 11); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 13)): [21022]
#
#  *** ***
#
# Current position: (131, 10); unvisited: [20021]
# Adjacent positions: [(131, 11)]
# Previous position: (129, 12); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: East
# Updated cost to reach ((131, 11)): [21022]
#
#  *** ***
#
# Current position: (138, 13); unvisited: [21021]
# Adjacent positions: [(137, 13)]
# Previous position: (131, 10); dx_p: 7; dy_p: 3
# Previous direction: None; New direction: North
# Updated cost to reach ((137, 13)): [22022]
#
#  *** ***
#
# Current position: (139, 14); unvisited: [21021]
# Adjacent positions: [(139, 15)]
# Previous position: (138, 13); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 15)): [22022]
#
#  *** ***
#
# Current position: (127, 3); unvisited: [21022]
# Adjacent positions: [(127, 4)]
# Previous position: (139, 14); dx_p: -12; dy_p: -11
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 4)): [22023]
#
#  *** ***
#
# Current position: (129, 1); unvisited: [21022]
# Adjacent positions: [(128, 1), (130, 1)]
# Previous position: (127, 3); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((128, 1)): [22023]
# Previous direction: None; New direction: South
# Updated cost to reach ((130, 1)): [22023]
#
#  *** ***
#
# Current position: (127, 11); unvisited: [21022]
# Adjacent positions: [(127, 10), (127, 12)]
# Previous position: (129, 1); dx_p: -2; dy_p: 10
# Previous direction: None; New direction: West
# Updated cost to reach ((127, 10)): [22023]
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 12)): [22023]
#
#  *** ***
#
# Current position: (129, 13); unvisited: [21022]
# Adjacent positions: [(128, 13), (130, 13), (129, 14)]
# Previous position: (127, 11); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((128, 13)): [22023]
# Previous direction: None; New direction: South
# Updated cost to reach ((130, 13)): [22023]
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 14)): [22023]
#
#  *** ***
#
# Current position: (131, 11); unvisited: [21022]
# Adjacent positions: [(132, 11)]
# Previous position: (129, 13); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((132, 11)): [22023]
#
#  *** ***
#
# Current position: (137, 13); unvisited: [22022]
# Adjacent positions: [(137, 14)]
# Previous position: (131, 11); dx_p: 6; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((137, 14)): [23023]
#
#  *** ***
#
# Current position: (139, 15); unvisited: [22022]
# Adjacent positions: [(139, 16)]
# Previous position: (137, 13); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 16)): [23023]
#
#  *** ***
#
# Current position: (127, 4); unvisited: [22023]
# Adjacent positions: [(127, 5)]
# Previous position: (139, 15); dx_p: -12; dy_p: -11
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 5)): [23024]
#
#  *** ***
#
# Current position: (128, 1); unvisited: [22023]
# Adjacent positions: [(127, 1)]
# Previous position: (127, 4); dx_p: 1; dy_p: -3
# Previous direction: None; New direction: North
# Updated cost to reach ((127, 1)): [23024]
#
#  *** ***
#
# Current position: (130, 1); unvisited: [22023]
# Adjacent positions: [(131, 1)]
# Previous position: (128, 1); dx_p: 2; dy_p: 0
# Previous direction: None; New direction: South
# Updated cost to reach ((131, 1)): [23024]
#
#  *** ***
#
# Current position: (127, 10); unvisited: [22023]
# Adjacent positions: [(127, 9)]
# Previous position: (130, 1); dx_p: -3; dy_p: 9
# Previous direction: None; New direction: West
# Updated cost to reach ((127, 9)): [23024]
#
#  *** ***
#
# Current position: (127, 12); unvisited: [22023]
# Adjacent positions: [(127, 13)]
# Previous position: (127, 10); dx_p: 0; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 13)): [23024]
#
#  *** ***
#
# Current position: (128, 13); unvisited: [22023]
# Adjacent positions: [(127, 13)]
# Previous position: (127, 12); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: North
# Updated cost to reach ((127, 13)): [23024, 23024]
#
#  *** ***
#
# Current position: (129, 14); unvisited: [22023]
# Adjacent positions: [(129, 15)]
# Previous position: (128, 13); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 15)): [23024]
#
#  *** ***
#
# Current position: (130, 13); unvisited: [22023]
# Adjacent positions: [(131, 13)]
# Previous position: (129, 14); dx_p: 1; dy_p: -1
# Previous direction: None; New direction: South
# Updated cost to reach ((131, 13)): [23024]
#
#  *** ***
#
# Current position: (132, 11); unvisited: [22023]
# Adjacent positions: [(133, 11)]
# Previous position: (130, 13); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((133, 11)): [23024]
#
#  *** ***
#
# Current position: (137, 14); unvisited: [23023]
# Adjacent positions: [(137, 15)]
# Previous position: (132, 11); dx_p: 5; dy_p: 3
# Previous direction: None; New direction: East
# Updated cost to reach ((137, 15)): [24024]
#
#  *** ***
#
# Current position: (139, 16); unvisited: [23023]
# Adjacent positions: [(139, 17)]
# Previous position: (137, 14); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 17)): [24024]
#
#  *** ***
#
# Current position: (127, 5); unvisited: [23024]
# Adjacent positions: [(126, 5), (127, 6)]
# Previous position: (139, 16); dx_p: -12; dy_p: -11
# Previous direction: None; New direction: North
# Updated cost to reach ((126, 5)): [24025]
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 6)): [24025]
#
#  *** ***
#
# Current position: (127, 1); unvisited: [23024]
# Adjacent positions: []
# Previous position: (127, 5); dx_p: 0; dy_p: -4
#
#  *** ***
#
# Current position: (131, 1); unvisited: [23024]
# Adjacent positions: []
# Previous position: (127, 1); dx_p: 4; dy_p: 0
#
#  *** ***
#
# Current position: (127, 9); unvisited: [23024]
# Adjacent positions: [(126, 9), (127, 8)]
# Previous position: (131, 1); dx_p: -4; dy_p: 8
# Previous direction: None; New direction: North
# Updated cost to reach ((126, 9)): [24025]
# Previous direction: None; New direction: West
# Updated cost to reach ((127, 8)): [24025]
#
#  *** ***
#
# Current position: (127, 13); unvisited: [23024, 23024]
# Adjacent positions: [(126, 13)]
# Previous position: (127, 9); dx_p: 0; dy_p: 4
# Previous direction: None; New direction: North
# Updated cost to reach ((126, 13)): [24025]
#
#  *** ***
#
# Current position: (129, 15); unvisited: [23024]
# Adjacent positions: [(128, 15), (129, 16)]
# Previous position: (127, 13); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((128, 15)): [24025]
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 16)): [24025]
#
#  *** ***
#
# Current position: (131, 13); unvisited: [23024]
# Adjacent positions: [(132, 13)]
# Previous position: (129, 15); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((132, 13)): [24025]
#
#  *** ***
#
# Current position: (133, 11); unvisited: [23024]
# Adjacent positions: [(134, 11)]
# Previous position: (131, 13); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((134, 11)): [24025]
#
#  *** ***
#
# Current position: (137, 15); unvisited: [24024]
# Adjacent positions: [(137, 16)]
# Previous position: (133, 11); dx_p: 4; dy_p: 4
# Previous direction: None; New direction: East
# Updated cost to reach ((137, 16)): [25025]
#
#  *** ***
#
# Current position: (139, 17); unvisited: [24024]
# Adjacent positions: []
# Previous position: (137, 15); dx_p: 2; dy_p: 2
#
#  *** ***
#
# Current position: (126, 5); unvisited: [24025]
# Adjacent positions: [(125, 5)]
# Previous position: (139, 17); dx_p: -13; dy_p: -12
# Previous direction: None; New direction: North
# Updated cost to reach ((125, 5)): [25026]
#
#  *** ***
#
# Current position: (127, 6); unvisited: [24025]
# Adjacent positions: [(127, 7)]
# Previous position: (126, 5); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 7)): [25026]
#
#  *** ***
#
# Current position: (126, 9); unvisited: [24025]
# Adjacent positions: [(125, 9)]
# Previous position: (127, 6); dx_p: -1; dy_p: 3
# Previous direction: None; New direction: North
# Updated cost to reach ((125, 9)): [25026]
#
#  *** ***
#
# Current position: (127, 8); unvisited: [24025]
# Adjacent positions: [(127, 7)]
# Previous position: (126, 9); dx_p: 1; dy_p: -1
# Previous direction: None; New direction: West
# Updated cost to reach ((127, 7)): [25026, 25026]
#
#  *** ***
#
# Current position: (126, 13); unvisited: [24025]
# Adjacent positions: [(125, 13)]
# Previous position: (127, 8); dx_p: -1; dy_p: 5
# Previous direction: None; New direction: North
# Updated cost to reach ((125, 13)): [25026]
#
#  *** ***
#
# Current position: (128, 15); unvisited: [24025]
# Adjacent positions: [(127, 15)]
# Previous position: (126, 13); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((127, 15)): [25026]
#
#  *** ***
#
# Current position: (129, 16); unvisited: [24025]
# Adjacent positions: [(129, 17)]
# Previous position: (128, 15); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 17)): [25026]
#
#  *** ***
#
# Current position: (132, 13); unvisited: [24025]
# Adjacent positions: [(133, 13)]
# Previous position: (129, 16); dx_p: 3; dy_p: -3
# Previous direction: None; New direction: South
# Updated cost to reach ((133, 13)): [25026]
#
#  *** ***
#
# Current position: (134, 11); unvisited: [24025]
# Adjacent positions: [(135, 11)]
# Previous position: (132, 13); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((135, 11)): [25026]
#
#  *** ***
#
# Current position: (137, 16); unvisited: [25025]
# Adjacent positions: [(137, 17)]
# Previous position: (134, 11); dx_p: 3; dy_p: 5
# Previous direction: None; New direction: East
# Updated cost to reach ((137, 17)): [26026]
#
#  *** ***
#
# Current position: (125, 5); unvisited: [25026]
# Adjacent positions: [(124, 5), (125, 4)]
# Previous position: (137, 16); dx_p: -12; dy_p: -11
# Previous direction: None; New direction: North
# Updated cost to reach ((124, 5)): [26027]
# Previous direction: None; New direction: West
# Updated cost to reach ((125, 4)): [26027]
#
#  *** ***
#
# Current position: (127, 7); unvisited: [25026, 25026]
# Adjacent positions: [(126, 7)]
# Previous position: (125, 5); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((126, 7)): [26027]
#
#  *** ***
#
# Current position: (125, 9); unvisited: [25026]
# Adjacent positions: [(124, 9), (125, 10)]
# Previous position: (127, 7); dx_p: -2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((124, 9)): [26027]
# Previous direction: None; New direction: East
# Updated cost to reach ((125, 10)): [26027]
#
#  *** ***
#
# Current position: (125, 13); unvisited: [25026]
# Adjacent positions: [(125, 14)]
# Previous position: (125, 9); dx_p: 0; dy_p: 4
# Previous direction: None; New direction: East
# Updated cost to reach ((125, 14)): [26027]
#
#  *** ***
#
# Current position: (127, 15); unvisited: [25026]
# Adjacent positions: [(127, 16)]
# Previous position: (125, 13); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 16)): [26027]
#
#  *** ***
#
# Current position: (129, 17); unvisited: [25026]
# Adjacent positions: [(129, 18)]
# Previous position: (127, 15); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 18)): [26027]
#
#  *** ***
#
# Current position: (133, 13); unvisited: [25026]
# Adjacent positions: [(134, 13)]
# Previous position: (129, 17); dx_p: 4; dy_p: -4
# Previous direction: None; New direction: South
# Updated cost to reach ((134, 13)): [26027]
#
#  *** ***
#
# Current position: (135, 11); unvisited: [25026]
# Adjacent positions: [(135, 10), (135, 12)]
# Previous position: (133, 13); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: West
# Updated cost to reach ((135, 10)): [26027]
# Previous direction: None; New direction: East
# Updated cost to reach ((135, 12)): [26027]
#
#  *** ***
#
# Current position: (137, 17); unvisited: [26026]
# Adjacent positions: [(136, 17)]
# Previous position: (135, 11); dx_p: 2; dy_p: 6
# Previous direction: None; New direction: North
# Updated cost to reach ((136, 17)): [27027]
#
#  *** ***
#
# Current position: (124, 5); unvisited: [26027]
# Adjacent positions: [(123, 5)]
# Previous position: (137, 17); dx_p: -13; dy_p: -12
# Previous direction: None; New direction: North
# Updated cost to reach ((123, 5)): [27028]
#
#  *** ***
#
# Current position: (125, 4); unvisited: [26027]
# Adjacent positions: [(125, 3)]
# Previous position: (124, 5); dx_p: 1; dy_p: -1
# Previous direction: None; New direction: West
# Updated cost to reach ((125, 3)): [27028]
#
#  *** ***
#
# Current position: (126, 7); unvisited: [26027]
# Adjacent positions: [(125, 7)]
# Previous position: (125, 4); dx_p: 1; dy_p: 3
# Previous direction: None; New direction: North
# Updated cost to reach ((125, 7)): [27028]
#
#  *** ***
#
# Current position: (124, 9); unvisited: [26027]
# Adjacent positions: [(123, 9)]
# Previous position: (126, 7); dx_p: -2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((123, 9)): [27028]
#
#  *** ***
#
# Current position: (125, 10); unvisited: [26027]
# Adjacent positions: [(125, 11)]
# Previous position: (124, 9); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((125, 11)): [27028]
#
#  *** ***
#
# Current position: (125, 14); unvisited: [26027]
# Adjacent positions: [(125, 15)]
# Previous position: (125, 10); dx_p: 0; dy_p: 4
# Previous direction: None; New direction: East
# Updated cost to reach ((125, 15)): [27028]
#
#  *** ***
#
# Current position: (127, 16); unvisited: [26027]
# Adjacent positions: [(127, 17)]
# Previous position: (125, 14); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 17)): [27028]
#
#  *** ***
#
# Current position: (129, 18); unvisited: [26027]
# Adjacent positions: [(129, 19)]
# Previous position: (127, 16); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 19)): [27028]
#
#  *** ***
#
# Current position: (134, 13); unvisited: [26027]
# Adjacent positions: [(135, 13)]
# Previous position: (129, 18); dx_p: 5; dy_p: -5
# Previous direction: None; New direction: South
# Updated cost to reach ((135, 13)): [27028]
#
#  *** ***
#
# Current position: (135, 10); unvisited: [26027]
# Adjacent positions: [(135, 9)]
# Previous position: (134, 13); dx_p: 1; dy_p: -3
# Previous direction: None; New direction: West
# Updated cost to reach ((135, 9)): [27028]
#
#  *** ***
#
# Current position: (135, 12); unvisited: [26027]
# Adjacent positions: [(135, 13)]
# Previous position: (135, 10); dx_p: 0; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((135, 13)): [27028, 27028]
#
#  *** ***
#
# Current position: (136, 17); unvisited: [27027]
# Adjacent positions: [(135, 17)]
# Previous position: (135, 12); dx_p: 1; dy_p: 5
# Previous direction: None; New direction: North
# Updated cost to reach ((135, 17)): [28028]
#
#  *** ***
#
# Current position: (123, 5); unvisited: [27028]
# Adjacent positions: [(123, 4)]
# Previous position: (136, 17); dx_p: -13; dy_p: -12
# Previous direction: None; New direction: West
# Updated cost to reach ((123, 4)): [28029]
#
#  *** ***
#
# Current position: (125, 3); unvisited: [27028]
# Adjacent positions: [(125, 2)]
# Previous position: (123, 5); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: West
# Updated cost to reach ((125, 2)): [28029]
#
#  *** ***
#
# Current position: (125, 7); unvisited: [27028]
# Adjacent positions: [(124, 7)]
# Previous position: (125, 3); dx_p: 0; dy_p: 4
# Previous direction: None; New direction: North
# Updated cost to reach ((124, 7)): [28029]
#
#  *** ***
#
# Current position: (123, 9); unvisited: [27028]
# Adjacent positions: [(122, 9), (123, 8)]
# Previous position: (125, 7); dx_p: -2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((122, 9)): [28029]
# Previous direction: None; New direction: West
# Updated cost to reach ((123, 8)): [28029]
#
#  *** ***
#
# Current position: (125, 11); unvisited: [27028]
# Adjacent positions: [(124, 11)]
# Previous position: (123, 9); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((124, 11)): [28029]
#
#  *** ***
#
# Current position: (125, 15); unvisited: [27028]
# Adjacent positions: [(125, 16)]
# Previous position: (125, 11); dx_p: 0; dy_p: 4
# Previous direction: None; New direction: East
# Updated cost to reach ((125, 16)): [28029]
#
#  *** ***
#
# Current position: (127, 17); unvisited: [27028]
# Adjacent positions: [(127, 18)]
# Previous position: (125, 15); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 18)): [28029]
#
#  *** ***
#
# Current position: (129, 19); unvisited: [27028]
# Adjacent positions: [(129, 20)]
# Previous position: (127, 17); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 20)): [28029]
#
#  *** ***
#
# Current position: (135, 13); unvisited: [27028, 27028]
# Adjacent positions: [(135, 14)]
# Previous position: (129, 19); dx_p: 6; dy_p: -6
# Previous direction: None; New direction: East
# Updated cost to reach ((135, 14)): [28029]
#
#  *** ***
#
# Current position: (135, 9); unvisited: [27028]
# Adjacent positions: [(135, 8)]
# Previous position: (135, 13); dx_p: 0; dy_p: -4
# Previous direction: None; New direction: West
# Updated cost to reach ((135, 8)): [28029]
#
#  *** ***
#
# Current position: (135, 17); unvisited: [28028]
# Adjacent positions: [(134, 17)]
# Previous position: (135, 9); dx_p: 0; dy_p: 8
# Previous direction: None; New direction: North
# Updated cost to reach ((134, 17)): [29029]
#
#  *** ***
#
# Current position: (123, 4); unvisited: [28029]
# Adjacent positions: [(123, 3)]
# Previous position: (135, 17); dx_p: -12; dy_p: -13
# Previous direction: None; New direction: West
# Updated cost to reach ((123, 3)): [29030]
#
#  *** ***
#
# Current position: (125, 2); unvisited: [28029]
# Adjacent positions: [(125, 1)]
# Previous position: (123, 4); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: West
# Updated cost to reach ((125, 1)): [29030]
#
#  *** ***
#
# Current position: (124, 7); unvisited: [28029]
# Adjacent positions: [(123, 7)]
# Previous position: (125, 2); dx_p: -1; dy_p: 5
# Previous direction: None; New direction: North
# Updated cost to reach ((123, 7)): [29030]
#
#  *** ***
#
# Current position: (122, 9); unvisited: [28029]
# Adjacent positions: [(121, 9)]
# Previous position: (124, 7); dx_p: -2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((121, 9)): [29030]
#
#  *** ***
#
# Current position: (123, 8); unvisited: [28029]
# Adjacent positions: [(123, 7)]
# Previous position: (122, 9); dx_p: 1; dy_p: -1
# Previous direction: None; New direction: West
# Updated cost to reach ((123, 7)): [29030, 29030]
#
#  *** ***
#
# Current position: (124, 11); unvisited: [28029]
# Adjacent positions: [(123, 11)]
# Previous position: (123, 8); dx_p: 1; dy_p: 3
# Previous direction: None; New direction: North
# Updated cost to reach ((123, 11)): [29030]
#
#  *** ***
#
# Current position: (125, 16); unvisited: [28029]
# Adjacent positions: [(125, 17)]
# Previous position: (124, 11); dx_p: 1; dy_p: 5
# Previous direction: None; New direction: East
# Updated cost to reach ((125, 17)): [29030]
#
#  *** ***
#
# Current position: (127, 18); unvisited: [28029]
# Adjacent positions: [(127, 19)]
# Previous position: (125, 16); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 19)): [29030]
#
#  *** ***
#
# Current position: (129, 20); unvisited: [28029]
# Adjacent positions: [(129, 21)]
# Previous position: (127, 18); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 21)): [29030]
#
#  *** ***
#
# Current position: (135, 14); unvisited: [28029]
# Adjacent positions: [(135, 15)]
# Previous position: (129, 20); dx_p: 6; dy_p: -6
# Previous direction: None; New direction: East
# Updated cost to reach ((135, 15)): [29030]
#
#  *** ***
#
# Current position: (135, 8); unvisited: [28029]
# Adjacent positions: [(135, 7)]
# Previous position: (135, 14); dx_p: 0; dy_p: -6
# Previous direction: None; New direction: West
# Updated cost to reach ((135, 7)): [29030]
#
#  *** ***
#
# Current position: (134, 17); unvisited: [29029]
# Adjacent positions: [(133, 17)]
# Previous position: (135, 8); dx_p: -1; dy_p: 9
# Previous direction: None; New direction: North
# Updated cost to reach ((133, 17)): [30030]
#
#  *** ***
#
# Current position: (123, 3); unvisited: [29030]
# Adjacent positions: []
# Previous position: (134, 17); dx_p: -11; dy_p: -14
#
#  *** ***
#
# Current position: (125, 1); unvisited: [29030]
# Adjacent positions: [(124, 1)]
# Previous position: (123, 3); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((124, 1)): [30031]
#
#  *** ***
#
# Current position: (123, 7); unvisited: [29030, 29030]
# Adjacent positions: [(122, 7)]
# Previous position: (125, 1); dx_p: -2; dy_p: 6
# Previous direction: None; New direction: North
# Updated cost to reach ((122, 7)): [30031]
#
#  *** ***
#
# Current position: (121, 9); unvisited: [29030]
# Adjacent positions: [(120, 9), (121, 10)]
# Previous position: (123, 7); dx_p: -2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((120, 9)): [30031]
# Previous direction: None; New direction: East
# Updated cost to reach ((121, 10)): [30031]
#
#  *** ***
#
# Current position: (123, 11); unvisited: [29030]
# Adjacent positions: [(123, 12)]
# Previous position: (121, 9); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((123, 12)): [30031]
#
#  *** ***
#
# Current position: (125, 17); unvisited: [29030]
# Adjacent positions: [(124, 17)]
# Previous position: (123, 11); dx_p: 2; dy_p: 6
# Previous direction: None; New direction: North
# Updated cost to reach ((124, 17)): [30031]
#
#  *** ***
#
# Current position: (127, 19); unvisited: [29030]
# Adjacent positions: [(126, 19)]
# Previous position: (125, 17); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((126, 19)): [30031]
#
#  *** ***
#
# Current position: (129, 21); unvisited: [29030]
# Adjacent positions: [(128, 21), (129, 22)]
# Previous position: (127, 19); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((128, 21)): [30031]
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 22)): [30031]
#
#  *** ***
#
# Current position: (135, 15); unvisited: [29030]
# Adjacent positions: []
# Previous position: (129, 21); dx_p: 6; dy_p: -6
#
#  *** ***
#
# Current position: (135, 7); unvisited: [29030]
# Adjacent positions: [(136, 7)]
# Previous position: (135, 15); dx_p: 0; dy_p: -8
# Previous direction: None; New direction: South
# Updated cost to reach ((136, 7)): [30031]
#
#  *** ***
#
# Current position: (133, 17); unvisited: [30030]
# Adjacent positions: [(133, 16)]
# Previous position: (135, 7); dx_p: -2; dy_p: 10
# Previous direction: None; New direction: West
# Updated cost to reach ((133, 16)): [31031]
#
#  *** ***
#
# Current position: (124, 1); unvisited: [30031]
# Adjacent positions: [(123, 1)]
# Previous position: (133, 17); dx_p: -9; dy_p: -16
# Previous direction: None; New direction: North
# Updated cost to reach ((123, 1)): [31032]
#
#  *** ***
#
# Current position: (122, 7); unvisited: [30031]
# Adjacent positions: [(121, 7)]
# Previous position: (124, 1); dx_p: -2; dy_p: 6
# Previous direction: None; New direction: North
# Updated cost to reach ((121, 7)): [31032]
#
#  *** ***
#
# Current position: (120, 9); unvisited: [30031]
# Adjacent positions: [(119, 9)]
# Previous position: (122, 7); dx_p: -2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((119, 9)): [31032]
#
#  *** ***
#
# Current position: (121, 10); unvisited: [30031]
# Adjacent positions: [(121, 11)]
# Previous position: (120, 9); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((121, 11)): [31032]
#
#  *** ***
#
# Current position: (123, 12); unvisited: [30031]
# Adjacent positions: [(123, 13)]
# Previous position: (121, 10); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((123, 13)): [31032]
#
#  *** ***
#
# Current position: (124, 17); unvisited: [30031]
# Adjacent positions: [(123, 17)]
# Previous position: (123, 12); dx_p: 1; dy_p: 5
# Previous direction: None; New direction: North
# Updated cost to reach ((123, 17)): [31032]
#
#  *** ***
#
# Current position: (126, 19); unvisited: [30031]
# Adjacent positions: [(125, 19)]
# Previous position: (124, 17); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((125, 19)): [31032]
#
#  *** ***
#
# Current position: (128, 21); unvisited: [30031]
# Adjacent positions: [(127, 21)]
# Previous position: (126, 19); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((127, 21)): [31032]
#
#  *** ***
#
# Current position: (129, 22); unvisited: [30031]
# Adjacent positions: [(129, 23)]
# Previous position: (128, 21); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((129, 23)): [31032]
#
#  *** ***
#
# Current position: (136, 7); unvisited: [30031]
# Adjacent positions: [(137, 7)]
# Previous position: (129, 22); dx_p: 7; dy_p: -15
# Previous direction: None; New direction: South
# Updated cost to reach ((137, 7)): [31032]
#
#  *** ***
#
# Current position: (133, 16); unvisited: [31031]
# Adjacent positions: [(133, 15)]
# Previous position: (136, 7); dx_p: -3; dy_p: 9
# Previous direction: None; New direction: West
# Updated cost to reach ((133, 15)): [32032]
#
#  *** ***
#
# Current position: (123, 1); unvisited: [31032]
# Adjacent positions: [(122, 1)]
# Previous position: (133, 16); dx_p: -10; dy_p: -15
# Previous direction: None; New direction: North
# Updated cost to reach ((122, 1)): [32033]
#
#  *** ***
#
# Current position: (121, 7); unvisited: [31032]
# Adjacent positions: [(120, 7), (121, 6)]
# Previous position: (123, 1); dx_p: -2; dy_p: 6
# Previous direction: None; New direction: North
# Updated cost to reach ((120, 7)): [32033]
# Previous direction: None; New direction: West
# Updated cost to reach ((121, 6)): [32033]
#
#  *** ***
#
# Current position: (119, 9); unvisited: [31032]
# Adjacent positions: [(118, 9), (119, 8)]
# Previous position: (121, 7); dx_p: -2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((118, 9)): [32033]
# Previous direction: None; New direction: West
# Updated cost to reach ((119, 8)): [32033]
#
#  *** ***
#
# Current position: (121, 11); unvisited: [31032]
# Adjacent positions: [(120, 11)]
# Previous position: (119, 9); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((120, 11)): [32033]
#
#  *** ***
#
# Current position: (123, 13); unvisited: [31032]
# Adjacent positions: [(122, 13), (123, 14)]
# Previous position: (121, 11); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((122, 13)): [32033]
# Previous direction: None; New direction: East
# Updated cost to reach ((123, 14)): [32033]
#
#  *** ***
#
# Current position: (123, 17); unvisited: [31032]
# Adjacent positions: [(122, 17)]
# Previous position: (123, 13); dx_p: 0; dy_p: 4
# Previous direction: None; New direction: North
# Updated cost to reach ((122, 17)): [32033]
#
#  *** ***
#
# Current position: (125, 19); unvisited: [31032]
# Adjacent positions: [(124, 19), (125, 20)]
# Previous position: (123, 17); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((124, 19)): [32033]
# Previous direction: None; New direction: East
# Updated cost to reach ((125, 20)): [32033]
#
#  *** ***
#
# Current position: (127, 21); unvisited: [31032]
# Adjacent positions: [(127, 22)]
# Previous position: (125, 19); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 22)): [32033]
#
#  *** ***
#
# Current position: (129, 23); unvisited: [31032]
# Adjacent positions: [(130, 23)]
# Previous position: (127, 21); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: South
# Updated cost to reach ((130, 23)): [32033]
#
#  *** ***
#
# Current position: (137, 7); unvisited: [31032]
# Adjacent positions: [(137, 8)]
# Previous position: (129, 23); dx_p: 8; dy_p: -16
# Previous direction: None; New direction: East
# Updated cost to reach ((137, 8)): [32033]
#
#  *** ***
#
# Current position: (133, 15); unvisited: [32032]
# Adjacent positions: [(132, 15)]
# Previous position: (137, 7); dx_p: -4; dy_p: 8
# Previous direction: None; New direction: North
# Updated cost to reach ((132, 15)): [33033]
#
#  *** ***
#
# Current position: (122, 1); unvisited: [32033]
# Adjacent positions: [(121, 1)]
# Previous position: (133, 15); dx_p: -11; dy_p: -14
# Previous direction: None; New direction: North
# Updated cost to reach ((121, 1)): [33034]
#
#  *** ***
#
# Current position: (120, 7); unvisited: [32033]
# Adjacent positions: [(119, 7)]
# Previous position: (122, 1); dx_p: -2; dy_p: 6
# Previous direction: None; New direction: North
# Updated cost to reach ((119, 7)): [33034]
#
#  *** ***
#
# Current position: (121, 6); unvisited: [32033]
# Adjacent positions: [(121, 5)]
# Previous position: (120, 7); dx_p: 1; dy_p: -1
# Previous direction: None; New direction: West
# Updated cost to reach ((121, 5)): [33034]
#
#  *** ***
#
# Current position: (118, 9); unvisited: [32033]
# Adjacent positions: [(117, 9)]
# Previous position: (121, 6); dx_p: -3; dy_p: 3
# Previous direction: None; New direction: North
# Updated cost to reach ((117, 9)): [33034]
#
#  *** ***
#
# Current position: (119, 8); unvisited: [32033]
# Adjacent positions: [(119, 7)]
# Previous position: (118, 9); dx_p: 1; dy_p: -1
# Previous direction: None; New direction: West
# Updated cost to reach ((119, 7)): [33034, 33034]
#
#  *** ***
#
# Current position: (120, 11); unvisited: [32033]
# Adjacent positions: [(119, 11)]
# Previous position: (119, 8); dx_p: 1; dy_p: 3
# Previous direction: None; New direction: North
# Updated cost to reach ((119, 11)): [33034]
#
#  *** ***
#
# Current position: (122, 13); unvisited: [32033]
# Adjacent positions: [(121, 13)]
# Previous position: (120, 11); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((121, 13)): [33034]
#
#  *** ***
#
# Current position: (123, 14); unvisited: [32033]
# Adjacent positions: [(123, 15)]
# Previous position: (122, 13); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((123, 15)): [33034]
#
#  *** ***
#
# Current position: (122, 17); unvisited: [32033]
# Adjacent positions: [(121, 17)]
# Previous position: (123, 14); dx_p: -1; dy_p: 3
# Previous direction: None; New direction: North
# Updated cost to reach ((121, 17)): [33034]
#
#  *** ***
#
# Current position: (124, 19); unvisited: [32033]
# Adjacent positions: [(123, 19)]
# Previous position: (122, 17); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((123, 19)): [33034]
#
#  *** ***
#
# Current position: (125, 20); unvisited: [32033]
# Adjacent positions: [(125, 21)]
# Previous position: (124, 19); dx_p: 1; dy_p: 1
# Previous direction: None; New direction: East
# Updated cost to reach ((125, 21)): [33034]
#
#  *** ***
#
# Current position: (127, 22); unvisited: [32033]
# Adjacent positions: [(127, 23)]
# Previous position: (125, 20); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((127, 23)): [33034]
#
#  *** ***
#
# Current position: (130, 23); unvisited: [32033]
# Adjacent positions: [(131, 23)]
# Previous position: (127, 22); dx_p: 3; dy_p: 1
# Previous direction: None; New direction: South
# Updated cost to reach ((131, 23)): [33034]
#
#  *** ***
#
# Current position: (137, 8); unvisited: [32033]
# Adjacent positions: [(137, 9)]
# Previous position: (130, 23); dx_p: 7; dy_p: -15
# Previous direction: None; New direction: East
# Updated cost to reach ((137, 9)): [33034]
#
#  *** ***
#
# Current position: (132, 15); unvisited: [33033]
# Adjacent positions: [(131, 15)]
# Previous position: (137, 8); dx_p: -5; dy_p: 7
# Previous direction: None; New direction: North
# Updated cost to reach ((131, 15)): [34034]
#
#  *** ***
#
# Current position: (121, 1); unvisited: [33034]
# Adjacent positions: [(120, 1)]
# Previous position: (132, 15); dx_p: -11; dy_p: -14
# Previous direction: None; New direction: North
# Updated cost to reach ((120, 1)): [34035]
#
#  *** ***
#
# Current position: (119, 7); unvisited: [33034, 33034]
# Adjacent positions: [(118, 7), (119, 6)]
# Previous position: (121, 1); dx_p: -2; dy_p: 6
# Previous direction: None; New direction: North
# Updated cost to reach ((118, 7)): [34035]
# Previous direction: None; New direction: West
# Updated cost to reach ((119, 6)): [34035]
#
#  *** ***
#
# Current position: (121, 5); unvisited: [33034]
# Adjacent positions: [(120, 5), (121, 4)]
# Previous position: (119, 7); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((120, 5)): [34035]
# Previous direction: None; New direction: West
# Updated cost to reach ((121, 4)): [34035]
#
#  *** ***
#
# Current position: (117, 9); unvisited: [33034]
# Adjacent positions: [(116, 9), (117, 8), (117, 10)]
# Previous position: (121, 5); dx_p: -4; dy_p: 4
# Previous direction: None; New direction: North
# Updated cost to reach ((116, 9)): [34035]
# Previous direction: None; New direction: West
# Updated cost to reach ((117, 8)): [34035]
# Previous direction: None; New direction: East
# Updated cost to reach ((117, 10)): [34035]
#
#  *** ***
#
# Current position: (119, 11); unvisited: [33034]
# Adjacent positions: [(119, 12)]
# Previous position: (117, 9); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((119, 12)): [34035]
#
#  *** ***
#
# Current position: (121, 13); unvisited: [33034]
# Adjacent positions: [(121, 14)]
# Previous position: (119, 11); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((121, 14)): [34035]
#
#  *** ***
#
# Current position: (123, 15); unvisited: [33034]
# Adjacent positions: []
# Previous position: (121, 13); dx_p: 2; dy_p: 2
#
#  *** ***
#
# Current position: (121, 17); unvisited: [33034]
# Adjacent positions: [(121, 16), (121, 18)]
# Previous position: (123, 15); dx_p: -2; dy_p: 2
# Previous direction: None; New direction: West
# Updated cost to reach ((121, 16)): [34035]
# Previous direction: None; New direction: East
# Updated cost to reach ((121, 18)): [34035]
#
#  *** ***
#
# Current position: (123, 19); unvisited: [33034]
# Adjacent positions: []
# Previous position: (121, 17); dx_p: 2; dy_p: 2
#
#  *** ***
#
# Current position: (125, 21); unvisited: [33034]
# Adjacent positions: [(124, 21)]
# Previous position: (123, 19); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((124, 21)): [34035]
#
#  *** ***
#
# Current position: (127, 23); unvisited: [33034]
# Adjacent positions: [(126, 23)]
# Previous position: (125, 21); dx_p: 2; dy_p: 2
# ...
# Updated cost to reach ((123, 113)): [187188]
#
#  *** ***
#
# Current position: (122, 115); unvisited: [186187]
# Adjacent positions: [(121, 115)]
# Previous position: (122, 113); dx_p: 0; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((121, 115)): [187188]
#
#  *** ***
#
# Current position: (124, 113); unvisited: [186187]
# Adjacent positions: [(123, 113)]
# Previous position: (122, 115); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((123, 113)): [187188, 187188]
#
#  *** ***
#
# Current position: (131, 118); unvisited: [186187]
# Adjacent positions: [(131, 117)]
# Previous position: (124, 113); dx_p: 7; dy_p: 5
# Previous direction: None; New direction: West
# Updated cost to reach ((131, 117)): [187188]
#
#  *** ***
#
# Current position: (131, 120); unvisited: [186187]
# Adjacent positions: [(131, 121)]
# Previous position: (131, 118); dx_p: 0; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((131, 121)): [187188]
#
#  *** ***
#
# Current position: (134, 121); unvisited: [186187]
# Adjacent positions: [(135, 121)]
# Previous position: (131, 120); dx_p: 3; dy_p: 1
# Previous direction: None; New direction: South
# Updated cost to reach ((135, 121)): [187188]
#
#  *** ***
#
# Current position: (136, 119); unvisited: [186187]
# Adjacent positions: [(137, 119)]
# Previous position: (134, 121); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((137, 119)): [187188]
#
#  *** ***
#
# Current position: (137, 112); unvisited: [186187]
# Adjacent positions: [(137, 111)]
# Previous position: (136, 119); dx_p: 1; dy_p: -7
# Previous direction: None; New direction: West
# Updated cost to reach ((137, 111)): [187188]
#
#  *** ***
#
# Current position: (139, 114); unvisited: [186187]
# Adjacent positions: [(139, 113)]
# Previous position: (137, 112); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: West
# Updated cost to reach ((139, 113)): [187188]
#
#  *** ***
#
# Current position: (139, 116); unvisited: [186187]
# Adjacent positions: [(139, 117)]
# Previous position: (139, 114); dx_p: 0; dy_p: 2
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 117)): [187188]
#
#  *** ***
#
# Current position: (25, 3); unvisited: [187188]
# Adjacent positions: [(25, 2)]
# Previous position: (139, 116); dx_p: -114; dy_p: -113
# Previous direction: None; New direction: West
# Updated cost to reach ((25, 2)): [188189]
#
#  *** ***
#
# Current position: (27, 1); unvisited: [187188]
# Adjacent positions: [(28, 1)]
# Previous position: (25, 3); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((28, 1)): [188189]
#
#  *** ***
#
# Current position: (31, 1); unvisited: [187188]
# Adjacent positions: [(30, 1)]
# Previous position: (27, 1); dx_p: 4; dy_p: 0
# Previous direction: None; New direction: North
# Updated cost to reach ((30, 1)): [188189]
#
#  *** ***
#
# Current position: (23, 1); unvisited: [187188]
# Adjacent positions: [(22, 1), (24, 1)]
# Previous position: (31, 1); dx_p: -8; dy_p: 0
# Previous direction: None; New direction: North
# Updated cost to reach ((22, 1)): [188189]
# Previous direction: None; New direction: South
# Updated cost to reach ((24, 1)): [188189]
#
#  *** ***
#
# Current position: (21, 15); unvisited: [187188]
# Adjacent positions: [(21, 16)]
# Previous position: (23, 1); dx_p: -2; dy_p: 14
# Previous direction: None; New direction: East
# Updated cost to reach ((21, 16)): [188189]
#
#  *** ***
#
# Current position: (31, 21); unvisited: [187188]
# Adjacent positions: [(31, 22)]
# Previous position: (21, 15); dx_p: 10; dy_p: 6
# Previous direction: None; New direction: East
# Updated cost to reach ((31, 22)): [188189]
#
#  *** ***
#
# Current position: (33, 19); unvisited: [187188]
# Adjacent positions: [(34, 19)]
# Previous position: (31, 21); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((34, 19)): [188189]
#
#  *** ***
#
# Current position: (47, 13); unvisited: [187188]
# Adjacent positions: [(46, 13)]
# Previous position: (33, 19); dx_p: 14; dy_p: -6
# Previous direction: None; New direction: North
# Updated cost to reach ((46, 13)): [188189]
#
#  *** ***
#
# Current position: (49, 11); unvisited: [187188]
# Adjacent positions: [(48, 11)]
# Previous position: (47, 13); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((48, 11)): [188189]
#
#  *** ***
#
# Current position: (51, 17); unvisited: [187188]
# Adjacent positions: [(51, 18)]
# Previous position: (49, 11); dx_p: 2; dy_p: 6
# Previous direction: None; New direction: East
# Updated cost to reach ((51, 18)): [188189]
#
#  *** ***
#
# Current position: (55, 17); unvisited: [187188, 187188]
# Adjacent positions: []
# Previous position: (51, 17); dx_p: 4; dy_p: 0
#
#  *** ***
#
# Current position: (57, 15); unvisited: [187188]
# Adjacent positions: [(58, 15)]
# Previous position: (55, 17); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((58, 15)): [188189]
#
#  *** ***
#
# Current position: (59, 9); unvisited: [187188]
# Adjacent positions: [(59, 8)]
# Previous position: (57, 15); dx_p: 2; dy_p: -6
# Previous direction: None; New direction: West
# Updated cost to reach ((59, 8)): [188189]
#
#  *** ***
#
# Current position: (59, 13); unvisited: [187188]
# Adjacent positions: []
# Previous position: (59, 9); dx_p: 0; dy_p: 4
#
#  *** ***
#
# Current position: (61, 11); unvisited: [187188]
# Adjacent positions: [(61, 12)]
# Previous position: (59, 13); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: East
# Updated cost to reach ((61, 12)): [188189]
#
#  *** ***
#
# Current position: (47, 33); unvisited: [187188]
# Adjacent positions: [(48, 33)]
# Previous position: (61, 11); dx_p: -14; dy_p: 22
# Previous direction: None; New direction: South
# Updated cost to reach ((48, 33)): [188189]
#
#  *** ***
#
# Current position: (53, 39); unvisited: [187188]
# Adjacent positions: []
# Previous position: (47, 33); dx_p: 6; dy_p: 6
#
#  *** ***
#
# Current position: (55, 37); unvisited: [187188]
# Adjacent positions: [(56, 37), (55, 38)]
# Previous position: (53, 39); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((56, 37)): [188189]
# Previous direction: None; New direction: East
# Updated cost to reach ((55, 38)): [188189]
#
#  *** ***
#
# Current position: (53, 27); unvisited: [187188]
# Adjacent positions: [(52, 27)]
# Previous position: (55, 37); dx_p: -2; dy_p: -10
# Previous direction: None; New direction: North
# Updated cost to reach ((52, 27)): [188189]
#
#  *** ***
#
# Current position: (55, 25); unvisited: [187188]
# Adjacent positions: [(54, 25)]
# Previous position: (53, 27); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((54, 25)): [188189]
#
#  *** ***
#
# Current position: (53, 19); unvisited: [187188]
# Adjacent positions: [(53, 20)]
# Previous position: (55, 25); dx_p: -2; dy_p: -6
# Previous direction: None; New direction: East
# Updated cost to reach ((53, 20)): [188189]
#
#  *** ***
#
# Current position: (65, 47); unvisited: [187188]
# Adjacent positions: [(65, 48)]
# Previous position: (53, 19); dx_p: 12; dy_p: 28
# Previous direction: None; New direction: East
# Updated cost to reach ((65, 48)): [188189]
#
#  *** ***
#
# Current position: (65, 15); unvisited: [187188]
# Adjacent positions: [(64, 15)]
# Previous position: (65, 47); dx_p: 0; dy_p: -32
# Previous direction: None; New direction: North
# Updated cost to reach ((64, 15)): [188189]
#
#  *** ***
#
# Current position: (67, 13); unvisited: [187188]
# Adjacent positions: [(67, 12)]
# Previous position: (65, 15); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: West
# Updated cost to reach ((67, 12)): [188189]
#
#  *** ***
#
# Current position: (89, 51); unvisited: [187188]
# Adjacent positions: [(90, 51)]
# Previous position: (67, 13); dx_p: 22; dy_p: 38
# Previous direction: None; New direction: South
# Updated cost to reach ((90, 51)): [188189]
#
#  *** ***
#
# Current position: (81, 75); unvisited: [187188]
# Adjacent positions: []
# Previous position: (89, 51); dx_p: -8; dy_p: 24
#
#  *** ***
#
# Current position: (85, 71); unvisited: [187188]
# Adjacent positions: [(84, 71)]
# Previous position: (81, 75); dx_p: 4; dy_p: -4
# Previous direction: None; New direction: North
# Updated cost to reach ((84, 71)): [188189]
#
#  *** ***
#
# Current position: (89, 75); unvisited: [187188]
# Adjacent positions: [(89, 76)]
# Previous position: (85, 71); dx_p: 4; dy_p: 4
# Previous direction: None; New direction: East
# Updated cost to reach ((89, 76)): [188189]
#
#  *** ***
#
# Current position: (97, 71); unvisited: [187188]
# Adjacent positions: [(96, 71)]
# Previous position: (89, 75); dx_p: 8; dy_p: -4
# Previous direction: None; New direction: North
# Updated cost to reach ((96, 71)): [188189]
#
#  *** ***
#
# Current position: (99, 81); unvisited: [187188]
# Adjacent positions: [(99, 82)]
# Previous position: (97, 71); dx_p: 2; dy_p: 10
# Previous direction: None; New direction: East
# Updated cost to reach ((99, 82)): [188189]
#
#  *** ***
#
# Current position: (105, 75); unvisited: [187188]
# Adjacent positions: []
# Previous position: (99, 81); dx_p: 6; dy_p: -6
#
#  *** ***
#
# Current position: (107, 77); unvisited: [187188]
# Adjacent positions: [(108, 77)]
# Previous position: (105, 75); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: South
# Updated cost to reach ((108, 77)): [188189]
#
#  *** ***
#
# Current position: (109, 79); unvisited: [187188]
# Adjacent positions: []
# Previous position: (107, 77); dx_p: 2; dy_p: 2
#
#  *** ***
#
# Current position: (113, 79); unvisited: [187188]
# Adjacent positions: [(114, 79), (113, 78)]
# Previous position: (109, 79); dx_p: 4; dy_p: 0
# Previous direction: None; New direction: South
# Updated cost to reach ((114, 79)): [188189]
# Previous direction: None; New direction: West
# Updated cost to reach ((113, 78)): [188189]
#
#  *** ***
#
# Current position: (89, 83); unvisited: [187188]
# Adjacent positions: [(89, 84)]
# Previous position: (113, 79); dx_p: -24; dy_p: 4
# Previous direction: None; New direction: East
# Updated cost to reach ((89, 84)): [188189]
#
#  *** ***
#
# Current position: (107, 97); unvisited: [187188]
# Adjacent positions: [(106, 97)]
# Previous position: (89, 83); dx_p: 18; dy_p: 14
# Previous direction: None; New direction: North
# Updated cost to reach ((106, 97)): [188189]
#
#  *** ***
#
# Current position: (105, 107); unvisited: [187188, 187188]
# Adjacent positions: [(105, 108)]
# Previous position: (107, 97); dx_p: -2; dy_p: 10
# Previous direction: None; New direction: East
# Updated cost to reach ((105, 108)): [188189]
#
#  *** ***
#
# Current position: (111, 109); unvisited: [187188]
# Adjacent positions: [(110, 109)]
# Previous position: (105, 107); dx_p: 6; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((110, 109)): [188189]
#
#  *** ***
#
# Current position: (119, 109); unvisited: [187188]
# Adjacent positions: [(118, 109)]
# Previous position: (111, 109); dx_p: 8; dy_p: 0
# Previous direction: None; New direction: North
# Updated cost to reach ((118, 109)): [188189]
#
#  *** ***
#
# Current position: (123, 113); unvisited: [187188, 187188]
# Adjacent positions: []
# Previous position: (119, 109); dx_p: 4; dy_p: 4
#
#  *** ***
#
# Current position: (121, 115); unvisited: [187188]
# Adjacent positions: [(120, 115)]
# Previous position: (123, 113); dx_p: -2; dy_p: 2
# Previous direction: None; New direction: North
# Updated cost to reach ((120, 115)): [188189]
#
#  *** ***
#
# Current position: (131, 117); unvisited: [187188]
# Adjacent positions: []
# Previous position: (121, 115); dx_p: 10; dy_p: 2
#
#  *** ***
#
# Current position: (131, 121); unvisited: [187188]
# Adjacent positions: [(130, 121)]
# Previous position: (131, 117); dx_p: 0; dy_p: 4
# Previous direction: None; New direction: North
# Updated cost to reach ((130, 121)): [188189]
#
#  *** ***
#
# Current position: (135, 121); unvisited: [187188]
# Adjacent positions: [(135, 122)]
# Previous position: (131, 121); dx_p: 4; dy_p: 0
# Previous direction: None; New direction: East
# Updated cost to reach ((135, 122)): [188189]
#
#  *** ***
#
# Current position: (137, 119); unvisited: [187188]
# Adjacent positions: [(138, 119), (137, 118)]
# Previous position: (135, 121); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: South
# Updated cost to reach ((138, 119)): [188189]
# Previous direction: None; New direction: West
# Updated cost to reach ((137, 118)): [188189]
#
#  *** ***
#
# Current position: (137, 111); unvisited: [187188]
# Adjacent positions: [(136, 111), (138, 111)]
# Previous position: (137, 119); dx_p: 0; dy_p: -8
# Previous direction: None; New direction: North
# Updated cost to reach ((136, 111)): [188189]
# Previous direction: None; New direction: South
# Updated cost to reach ((138, 111)): [188189]
#
#  *** ***
#
# Current position: (139, 113); unvisited: [187188]
# Adjacent positions: [(139, 112)]
# Previous position: (137, 111); dx_p: 2; dy_p: 2
# Previous direction: None; New direction: West
# Updated cost to reach ((139, 112)): [188189]
#
#  *** ***
#
# Current position: (139, 117); unvisited: [187188]
# Adjacent positions: [(138, 117), (139, 118)]
# Previous position: (139, 113); dx_p: 0; dy_p: 4
# Previous direction: None; New direction: North
# Updated cost to reach ((138, 117)): [188189]
# Previous direction: None; New direction: East
# Updated cost to reach ((139, 118)): [188189]
#
#  *** ***
#
# Current position: (25, 2); unvisited: [188189]
# Adjacent positions: [(25, 1)]
# Previous position: (139, 117); dx_p: -114; dy_p: -115
# Previous direction: None; New direction: West
# Updated cost to reach ((25, 1)): [189190]
#
#  *** ***
#
# Current position: (28, 1); unvisited: [188189]
# Adjacent positions: [(29, 1)]
# Previous position: (25, 2); dx_p: 3; dy_p: -1
# Previous direction: None; New direction: South
# Updated cost to reach ((29, 1)): [189190]
#
#  *** ***
#
# Current position: (30, 1); unvisited: [188189]
# Adjacent positions: [(29, 1)]
# Previous position: (28, 1); dx_p: 2; dy_p: 0
# Previous direction: None; New direction: North
# Updated cost to reach ((29, 1)): [189190, 189190]
#
#  *** ***
#
# Current position: (22, 1); unvisited: [188189]
# Adjacent positions: [(21, 1)]
# Previous position: (30, 1); dx_p: -8; dy_p: 0
# Previous direction: None; New direction: North
# Updated cost to reach ((21, 1)): [189190]
#
#  *** ***
#
# Current position: (24, 1); unvisited: [188189]
# Adjacent positions: [(25, 1)]
# Previous position: (22, 1); dx_p: 2; dy_p: 0
# Previous direction: None; New direction: South
# Updated cost to reach ((25, 1)): [189190, 189190]
#
#  *** ***
#
# Current position: (21, 16); unvisited: [188189]
# Adjacent positions: [(21, 17)]
# Previous position: (24, 1); dx_p: -3; dy_p: 15
# Previous direction: None; New direction: East
# Updated cost to reach ((21, 17)): [189190]
#
#  *** ***
#
# Current position: (31, 22); unvisited: [188189]
# Adjacent positions: [(31, 23)]
# Previous position: (21, 16); dx_p: 10; dy_p: 6
# Previous direction: None; New direction: East
# Updated cost to reach ((31, 23)): [189190]
#
#  *** ***
#
# Current position: (34, 19); unvisited: [188189]
# Adjacent positions: [(35, 19)]
# Previous position: (31, 22); dx_p: 3; dy_p: -3
# Previous direction: None; New direction: South
# Updated cost to reach ((35, 19)): [189190]
#
#  *** ***
#
# Current position: (46, 13); unvisited: [188189]
# Adjacent positions: [(45, 13)]
# Previous position: (34, 19); dx_p: 12; dy_p: -6
# Previous direction: None; New direction: North
# Updated cost to reach ((45, 13)): [189190]
#
#  *** ***
#
# Current position: (48, 11); unvisited: [188189]
# Adjacent positions: [(47, 11)]
# Previous position: (46, 13); dx_p: 2; dy_p: -2
# Previous direction: None; New direction: North
# Updated cost to reach ((47, 11)): [189190]
#
#  *** ***
#
# Current position: (51, 18); unvisited: [188189]
# Adjacent positions: [(51, 19)]
# Previous position: (48, 11); dx_p: 3; dy_p: 7
# Previous direction: None; New direction: East
# Updated cost to reach ((51, 19)): [189190]
#
#  *** ***
#
# Current position: (58, 15); unvisited: [188189]
# Adjacent positions: [(59, 15)]
# Previous position: (51, 18); dx_p: 7; dy_p: -3
# Previous direction: None; New direction: South
# Updated cost to reach ((59, 15)): [189190]
#
#  *** ***
#
# Current position: (59, 8); unvisited: [188189]
# Adjacent positions: [(59, 7)]
# Previous position: (58, 15); dx_p: 1; dy_p: -7
# Previous direction: None; New direction: West
# Updated cost to reach ((59, 7)): [189190]
